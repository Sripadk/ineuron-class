# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind = 'area')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', alpha = 0.4)
# Alpha is a paramater to control colour shading. 
# More the alha darker the colour
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area',alpha = 0.3,stacked = False )
# This function stacked will help in changing the scale of the graph)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# To find the relation between sepal legth and sepal width
df.plot.scatter(x = 'sepal_length', y='sepal_width')
# This shows that there is no excat relateion 
# The data set is excatly distributed
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# To find the relation between sepal legth and petal length
df.plot.scatter(x = 'sepal_length', y='petal_length')
# This shows that as sepal length increases the petal length also increases.
# thus there is a linear relation between sepal length and petal length.
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# Colour control 
df.plot.scatter(x = 'sepal_length', y='petal_length', c = 'sepal_width')

# c = 'sepal_width' : This will show the bar for sepal_width.
# sepal width starts from 2 and will go till 4.5
# as the scale progressess the bar becomes darker.
# The colour of each scatter plot dot is decided by the bar of sepal_width.
# lighter colour shows smaller alue of sepal _width at that dot.
# darker colour of the dot shows that value of sepal_width is high at that dot.
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y='petal_length', c = 'sepal_width', s = 10)
# s= 10: this is the size of the dot scatter plot
# s = 10 to 1000. 
# s = df['sepal_length']*20
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y='petal_length', s = 40)
# s = df['sepal_length']*40 : this varies the size depending on the column values 'sepal_lenght'
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y='petal_length', gridsize = 15)
# In hexabin, grid size increases, the plot hexagon size decreases
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y='petal_length', gridsize = 15, cmap="viridis")
# In hexabin, grid size increases, the plot hexagon size decreases
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # 3D plot

# %%
from mpl_toolkits import mplot3d

# %%
# providing x,y,z coordinates
x = np.linspace(-1,6,30)
y = np.linspace(-1,6,30)
z = x + y

# %%
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
# Creating an axes:
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z,)

# %%
# Random values 3D graph
x = np.random.randint(1,10,10)
y = np.random.randint(10,20,10)
z = x + y
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)

# %%
# implementing 3D graph with df
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# implementing 3D graph with df
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['sepal_width'], df['petal_length'])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
# size of the window.
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Bar Graph

# %%
# Graph drawn for the sasme df dataframe
df.iloc[5:11].plot.bar(figsize = (20,10), )
# Out:
# <AxesSubplot:>

# %%
# comparision in the same row no 5
df.iloc[5:6].plot.bar(figsize = (20,10), )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # plotting graph in horizontal direction

# %%
df.iloc[5:7].plot.barh(figsize = (20,10))
# plotted for 2 rows
# Out:
# <AxesSubplot:>

# %% [markdown]
# Histogram

# %%
df.plot.hist()
# Histogam tells us the range (x axis) and frequency(y axis)
# like petal length from 0 to 1 we have 40-60 frequency of petal_length data
# Histogram is used to check the range and frequency of the datapoints.
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# histogram for sepal_lenght only
df['sepal_length'].plot.hist(figsize = (20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# seperate histograms for all columns
df.hist(figsize=(20,10), color = 'g', alpha = 0.8)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# get colour from colour code online
df.hist(figsize=(20,10), color = '#207398', alpha = 0.8)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# Workin on cufflinks

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="01cacba3-c69c-41e8-9953-9a7cde5ccd42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length', y = 'petal_length', kind = 'scatter', mode = 'markers')
# Out:
# <div>                            <div id="49ec85f9-0efa-4809-8a02-7deabcb83519" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'bubble',x = 'sepal_length',y = 'sepal_width',size = 'petal_length')
# Out:
# <div>                            <div id="3b7e2e3f-152a-494d-a855-830f7f953cbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'bubble3d',z = 'petal_width', x = 'sepal_length',y = 'sepal_width',size = 'petal_length')
# Out:
# <div>                            <div id="8c5956c8-1988-4869-88c3-25e5ef3eed20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Making a new data set

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # To find out the the relation between total_bill and tip

# %%
df1.plot.scatter(x = 'total_bill', y = 'tip')
# THis is done by matplot lib
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Executing the same via iplot: plotly
df1.iplot(x = 'total_bill', y = 'tip', kind = 'scatter', mode = 'markers')
# Out:
# <div>                            <div id="34e59686-48f1-4446-924f-cf6bb50b26d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Executing the same graph via a seaborn Library

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# To find out the smokers and non smokers in pandas
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
# To find out the smokers and non smokers in the same graph
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'smoker')
this shows that the person giving the biggest tips are smokers.

# %%
# To group the data in terms of two parameters
# To find out the smokers/non smokers and 'time: lunch/Dinner' 
# in the same graph
# The parameters, stye and hue just reates grouping operations.
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'time', style = 'smoker')

# %%
# I would want to a graph plot for those who come for dinner and lunch seperately
sns.relplot(x = 'total_bill', y = 'tip', data = df1, col = 'time')
# This shows that majority of people are coming for dinner and lesser 
# for lunch

# %%
# for df data set
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x = 'sepal_length', y = 'petal_length', data = df , col = 'species')
# Thus all types of species have different graphs

# %%
# back to tips data set.
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# To know day wise how manay people coming.
sns.relplot(x = 'total_bill', y = 'tip', data = df1, col = 'day')
# This shows that people are not coming on Mon, tue, wed.
# and people coming on saturday & sunday are more

# %%
# plotting catagory wise data. It i called catagorical plot.
sns.catplot(x = 'day', y = 'total_bill', data = df1)

# %%
# Pair plot.
sns.pairplot(df1)
# All columns vs all columns comparision.

# %%
# pair plot for df data
sns.pairplot(df)

# %%
# Same graph with plot library
df.scatter_matrix()
# Out:
# <div>                            <div id="a68a6b1d-5fa0-402f-954f-f783bb0af0be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.scatter_matrix()
# Change the catagorical columns into values (ex: for yes = 1, & No = 0)
# or ex : sun = 1, mon =2, tues = 3, and so on. then youo will get the graph
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 df1.scatter_matrix()
#
# File ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py:1280, in _scatter_matrix(self, theme, bins, color, size, asFigure, **iplot_kwargs)
#    1259 def _scatter_matrix(self,theme=None,bins=10,color='grey',size=2, asFigure=False, **iplot_kwargs):
#    1260 	"""
#    1261 	Displays a matrix with scatter plot for each pair of
#    1262 	Series in the DataFrame.
#    (...)
#    1278 			Keyword arguments to pass through to `iplot`
#    1279 	"""
# -> 1280 	sm=tools.scatter_matrix(self,theme=theme,bins=bins,color=color,size=size)
#    1281 	if asFigure:
#    1282 		return sm
#
# File ~\anaconda3\lib\site-packages\cufflinks\tools.py:1020, in scatter_matrix(df, theme, bins, color, size)
#    1018 			figs.append(fig)
#    1019 		else:
# ...

# %% [markdown]
# ## Please use online matplot library or seaborn or plotly library to get each type of graphs.

# %%
# joint plot. This provides two plots w.r.t the same data set as below.
# graphs are scatter plot and histogrram.

sns.jointplot(x = df1.total_bill, y = df1.tip)

# %%
# instead of scatter plot if we want hexabin plot. then change the kind

sns.jointplot(x = df1.total_bill, y = df1.tip, kind = 'hex')

# %%
# pairplot
sns.pairplot(df1)

# %%
# Regression plot.
sns.regplot(x = df1.total_bill, y = df1.tip)
# This will also provide the best fit regression line.
# Now to change the fig size in seaborn you need to execute the below line
sns.set(rc = {'figure.figsize':(20,10)})

# %% [markdown]
# ## For code for matplot lib, seaborn or plotly, check their documentation website for the respective outputs

# %%
df2 = sns.load_dataset('car_crashes')

# %%
df2
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# cufflinks - https://github.com/santosjorge/cufflinks
# plotly - https://plotly.com/python/plotly-express/
# seaborn - https://seaborn.pydata.org/index.html
# matplotlib - https://matplotlib.org/stable/index.html
#
# These are the links for the respective documentation
